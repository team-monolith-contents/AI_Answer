# %% [markdown]
# **[문제1] 현재의 직업 중 인공지능의 등장으로 인해 사라질 직업과 그렇게 생각한 이유를 적어보세요.**
#
# - 번역 작가 : 인공지능의 번역 실력이 점점 좋아지고 있습니다.
# - 디자이너 : 이미지 생성형 인공지능의 그림 실력이 점점 좋아지고 있습니다.

# %% [markdown]
# **[문제2] 인공지능 번역기를 활용했을 때의 장점과 단점을 한가지씩 적어보세요.**
#
# - 많은 시간이 걸리지 않고 외국어의 의미를 알 수 있지만, 특별한 기술 용어 등은 다른 의미로 번역된 경우도 있습니다.

# %% [markdown]
# **[문제3] 인공지능 기술로 인해 소외받는 사람들에는 누가 있는지 2가지 이상의 사례를 적어보세요.**
#
# - 기술의 변화를 자주 접하지 못하는 노인
# - 사람이 많은 생활하는 수도권과 멀리 떨어진 소외 지역 아이들

# %% [markdown]
# **[문제4] 인공지능 기술의 발전은 막을 수 없는 흐름입니다. "시각장애인의 키오스크 활용"을 보다 편리하게 만들 수 있는 방법을 적어보세요.**
#
# - 키오스크를 터치할 때마다 음성으로 안내
# - 점자로 화면을 만들고, 터치는 누르는 방식으로 바꿈

# %% [markdown]
# **[문제5] ChatGPT는 위 6가지 핵심역량 중 어떤 역량을 인공지능 사회에 가장 필요한 역량이라고 생각할까요? ChatGPT에 질문해봅시다.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **[문제6] 문제5의 ChatGPT에서 출력한 내용에 대한 내 생각을 적어보세요.**
#
# 앞으로 미래에 인공지능이 인간의 생활에 개입이 많아지고 판단과 결정을 인공지능에게 맡기는 일이 많아질 것이라고 생각합니다. 모든 판단과 결정을 인공지능에게 맡기지 말고 지속적인 관심과 비판의식으로 주도권을 인간이 갖기 위해서 ChatGPT가 말한 것처럼 지식정보처리 역량이 필요하다고 생각합니다.
